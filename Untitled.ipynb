# %%
import seaborn as sns

# %%
# %matplotlib inline

# %%
tips=sns.load_dataset('tips')

# %%
flights=sns.load_dataset('flights')

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
flights.head()
# Out:
#    year     month  passengers
# 0  1949   January         112
# 1  1949  February         118
# 2  1949     March         132
# 3  1949     April         129
# 4  1949       May         121

# %%
flights.pivot_table(values='passengers',index='month',columns='year')
# Out:
# year       1949  1950  1951  1952  1953  1954  1955  1956  1957  1958  1959  \
# month
# January     112   115   145   171   196   204   242   284   315   340   360
# February    118   126   150   180   196   188   233   277   301   318   342
# March       132   141   178   193   236   235   267   317   356   362   406
# April       129   135   163   181   235   227   269   313   348   348   396
# May         121   125   172   183   229   234   270   318   355   363   420
# June        135   149   178   218   243   264   315   374   422   435   472
# July        148   170   199   230   264   302   364   413   465   491   548
# August      148   170   199   242   272   293   347   405   467   505   559
# September   136   158   184   209   237   259   312   355   404   404   463
# October     119   133   162   191   211   229   274   306   347   359   407
# November    104   114   146   172   180   203   237   271   305   310   362
# ...

# %%
flights.pivot_table(values='passengers',index='year',columns='month')
# Out:
# month  January  February  March  April  May  June  July  August  September  \
# year
# 1949       112       118    132    129  121   135   148     148        136
# 1950       115       126    141    135  125   149   170     170        158
# 1951       145       150    178    163  172   178   199     199        184
# 1952       171       180    193    181  183   218   230     242        209
# 1953       196       196    236    235  229   243   264     272        237
# 1954       204       188    235    227  234   264   302     293        259
# 1955       242       233    267    269  270   315   364     347        312
# 1956       284       277    317    313  318   374   413     405        355
# 1957       315       301    356    348  355   422   465     467        404
# 1958       340       318    362    348  363   435   491     505        404
# 1959       360       342    406    396  420   472   548     559        463
# ...

# %%
pflights=flights.pivot_table(values='passengers',index='month',columns='year')
sns.heatmap(pflights)

# %%
sns.heatmap(pflights,cmap='coolwarm',linecolor='white',linewidths=5)

# %%
#clustermap

# %%
sns.clustermap(pflights)

# %%
sns.clustermap(pflights,cmap='Set1',standard_scale=1)

# %%
#Grids

# %%
iris=sns.load_dataset("iris")

# %%
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
import matplotlib.pyplot as plt
g=sns.PairGrid(iris)
g.map(plt.scatter)

# %%
import matplotlib.pyplot as plt
g=sns.PairGrid(iris)
g.map_diag(sns.distplot)
g.map_upper(plt.scatter)
g.map_lower(sns.kdeplot)

# %%
g=sns.PairGrid(iris)
g.map(plt.scatter)

# %%
sns.pairplot(iris,palette='Set1',hue='species')

# %%
#facet grid

# %%
g=sns.FacetGrid(tips,col='time',row='smoker')
g=g.map(plt.hist,"total_bill")

# %%
g=sns.FacetGrid(tips,col='time',row='smoker',hue='sex')
g=g.map(plt.hist,"total_bill")

# %%
g=sns.FacetGrid(tips,col='time',row='smoker',hue='sex')
g=g.map(plt.hist,"total_bill").add_legend()

# %%
g=sns.FacetGrid(tips,col='time',row='smoker',hue='sex')
g=g.map(plt.scatter,"total_bill","tip").add_legend()

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
g=sns.JointGrid(x="total_bill",y="tip",data=tips)
g=g.plot(sns.regplot,sns.distplot)

# %%
#Regression plots

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.lmplot(x='total_bill',y='tip',data=tips)

# %%
sns.lmplot(x='total_bill',y='tip',data=tips,hue='sex')

# %%
sns.lmplot(x='total_bill',y='tip',data=tips,hue='sex',palette='rainbow',markers=['o','v'])

# %%
sns.lmplot(x='total_bill',y='tip',data=tips,hue='sex',palette='rainbow',markers=['o','v'],scatter_kws={'s':500})

# %%
sns.lmplot(x='total_bill',y='tip',data=tips,col='time',row='sex')

# %%
sns.lmplot(x='total_bill',y='tip',data=tips,col='day',hue='sex',palette='Set1')
